# %%
import feedparser
import pprint
import requests 
import pandas as pd
import numpy as np

# %%
# Listado de data sets disponible en opendata   
parameters = {'rows': '1000'}

url = 'http://opendata-ajuntament.barcelona.cat/data/api/3/action/package_search'
response = requests.get(url,params=parameters)
# Incluimos a tabla pandas Data sets contienen diferentes fuentes de datos columna resources
catalogo = pd.DataFrame(response.json()['result']['results']) 

# Creamos tabla con las fuentes de datos del catalogo

i = 0
for index, row in catalogo.iterrows():
    if i== 0:
        fuente_datos = pd.DataFrame(row['resources']) 
        fuente_datos['code'] = row['code']   
    i = 1
    aux =  pd.DataFrame(row['resources'])
    aux['code'] = row['code']
    fuente_datos = fuente_datos.append(aux)
fuente_datos = fuente_datos[['code','size', 'description', 'format' , 'downloads_absolute', 'token_required', 'url',  'name']]

# %%
catalogo[['code', 'title', 'frequency', 'fuente', 'relationships_as_object']]
# Out:
#                       code                                              title  \
# 0              np-piscines  Outdoor and covered swimming pools in the city...
# 1                 np-molls                     Docks in the city of Barcelona
# 2               np-platges                   Beaches in the city of Barcelona
# 3       np-quioscs-tramits  Punt BCN. Procedures' kiosks in the city of Ba...
# 4             np umbracles                 Umbracles in the city of Barcelona
# ..                     ...                                                ...
# 518        MAPA_URBANISTIC                 Urban map of the city of Barcelona
# 519  MAPA_BASE_DE_VIALITAT     Base map of viability of the city of Barcelona
# 520         MAPA_PARCELARI                Land plots in the city of Barcelona
# 521                  FRASE  Traffic incidence notices of the city of Barce...
# 522             ITINERARIS  Traffic state information in the city of Barce...
#
#           frequency                                        fuente  \
# 0          SETMANAL                       Ajuntament de Barcelona
# 1          SETMANAL                       Ajuntament de Barcelona
# 2          SETMANAL                       Ajuntament de Barcelona
# 3          SETMANAL                       Ajuntament de Barcelona
# 4          SETMANAL                       Ajuntament de Barcelona
# ..              ...                                           ...
# 518       IMMEDIATA           Ajuntament de Barcelona - Geoportal
# 519  PETICIO_NEGOCI           Ajuntament de Barcelona - Geoportal
# 520  PETICIO_NEGOCI                     Ajuntament de Barcelona
# 521     CINC_MINUTS  Web del trànsit de l'Ajuntament de Barcelona
# 522     CINC_MINUTS  Web del trànsit de l'Ajuntament de Barcelona
#
#     relationships_as_object
# 0                        []
# 1                        []
# 2                        []
# 3                        []
# 4                        []
# ..                      ...
# 518                      []
# 519                      []
# 520                      []
# 521                      []
# 522                      []
#
# [523 rows x 5 columns]

# %%
fuente_datos[fuente_datos.code == 'ITINERARIS' ]
# Out:
#           code  size description format downloads_absolute token_required  \
# 0   ITINERARIS  None                DAT             395893            NaN
# 1   ITINERARIS  None                CSV                225             No
# 2   ITINERARIS  None                CSV                160             No
# 3   ITINERARIS  None                CSV                132             No
# 4   ITINERARIS  None                CSV                111             No
# 5   ITINERARIS  None                CSV                114             No
# 6   ITINERARIS  None                CSV                 73             No
# 7   ITINERARIS  None                CSV                 55             No
# 8   ITINERARIS  None                CSV                 40             No
# 9   ITINERARIS  None                CSV                 28             No
# 10  ITINERARIS  None                CSV                 23            NaN
# 11  ITINERARIS  None                CSV                  1            NaN
# 12  ITINERARIS  None                CSV                515             No
# 13  ITINERARIS  None                CSV                446             No
# 14  ITINERARIS  None                CSV                910             No
# 15  ITINERARIS  None                CSV                228             No
# 16  ITINERARIS  None                CSV                191             No
# 17  ITINERARIS  None                CSV                178             No
# 18  ITINERARIS  None                CSV                196             No
# 19  ITINERARIS  None                CSV                181             No
# 20  ITINERARIS  None                CSV                195             No
# 21  ITINERARIS  None                CSV                203             No
# 22  ITINERARIS  None                CSV                166             No
# 23  ITINERARIS  None                CSV                199             No
# 24  ITINERARIS  None                CSV                589             No
# 25  ITINERARIS  None                CSV                519             No
# 26  ITINERARIS  None                CSV                507             No
# 27  ITINERARIS  None                CSV                511             No
# 28  ITINERARIS  None                CSV                486             No
# 29  ITINERARIS  None                CSV                458             No
# 30  ITINERARIS  None                CSV                423             No
# 31  ITINERARIS  None                CSV                435             No
# 32  ITINERARIS  None                CSV                450             No
# 33  ITINERARIS  None                CSV                423             No
# 34  ITINERARIS  None                CSV                435             No
# 35  ITINERARIS  None                CSV                421             No
# 36  ITINERARIS  None                CSV                571             No
# 37  ITINERARIS  None                CSV                504             No
# 38  ITINERARIS  None                CSV                507             No
# 39  ITINERARIS  None                CSV                499             No
# 40  ITINERARIS  None                CSV                491             No
# 41  ITINERARIS  None                CSV                477             No
# 42  ITINERARIS  None                CSV                459             No
# 43  ITINERARIS  None                CSV                465             No
# 44  ITINERARIS  None                CSV                473             No
# 45  ITINERARIS  None                CSV                489             No
# 46  ITINERARIS  None                CSV                473             No
# 47  ITINERARIS  None                CSV                438             No
# 48  ITINERARIS  None                CSV                544             No
# 49  ITINERARIS  None                CSV                492             No
#
#                                                   url  \
# 0   https://opendata-ajuntament.barcelona.cat/data...
# 1   https://opendata-ajuntament.barcelona.cat/data...
# 2   https://opendata-ajuntament.barcelona.cat/data...
# 3   https://opendata-ajuntament.barcelona.cat/data...
# 4   https://opendata-ajuntament.barcelona.cat/data...
# 5   https://opendata-ajuntament.barcelona.cat/data...
# 6   https://opendata-ajuntament.barcelona.cat/data...
# 7   https://opendata-ajuntament.barcelona.cat/data...
# 8   https://opendata-ajuntament.barcelona.cat/data...
# 9   https://opendata-ajuntament.barcelona.cat/data...
# 10  https://opendata-ajuntament.barcelona.cat/data...
# 11  https://opendata-ajuntament.barcelona.cat/data...
# 12  https://opendata-ajuntament.barcelona.cat/data...
# 13  https://opendata-ajuntament.barcelona.cat/data...
# 14  https://opendata-ajuntament.barcelona.cat/data...
# 15  https://opendata-ajuntament.barcelona.cat/data...
# 16  https://opendata-ajuntament.barcelona.cat/data...
# 17  https://opendata-ajuntament.barcelona.cat/data...
# 18  https://opendata-ajuntament.barcelona.cat/data...
# 19  https://opendata-ajuntament.barcelona.cat/data...
# 20  https://opendata-ajuntament.barcelona.cat/data...
# 21  https://opendata-ajuntament.barcelona.cat/data...
# 22  https://opendata-ajuntament.barcelona.cat/data...
# 23  https://opendata-ajuntament.barcelona.cat/data...
# 24  https://opendata-ajuntament.barcelona.cat/data...
# 25  https://opendata-ajuntament.barcelona.cat/data...
# 26  https://opendata-ajuntament.barcelona.cat/data...
# 27  https://opendata-ajuntament.barcelona.cat/data...
# 28  https://opendata-ajuntament.barcelona.cat/data...
# 29  https://opendata-ajuntament.barcelona.cat/data...
# 30  https://opendata-ajuntament.barcelona.cat/data...
# 31  https://opendata-ajuntament.barcelona.cat/data...
# 32  https://opendata-ajuntament.barcelona.cat/data...
# 33  https://opendata-ajuntament.barcelona.cat/data...
# 34  https://opendata-ajuntament.barcelona.cat/data...
# 35  https://opendata-ajuntament.barcelona.cat/data...
# 36  https://opendata-ajuntament.barcelona.cat/data...
# 37  https://opendata-ajuntament.barcelona.cat/data...
# 38  https://opendata-ajuntament.barcelona.cat/data...
# 39  https://opendata-ajuntament.barcelona.cat/data...
# 40  https://opendata-ajuntament.barcelona.cat/data...
# 41  https://opendata-ajuntament.barcelona.cat/data...
# 42  https://opendata-ajuntament.barcelona.cat/data...
# 43  https://opendata-ajuntament.barcelona.cat/data...
# 44  https://opendata-ajuntament.barcelona.cat/data...
# 45  https://opendata-ajuntament.barcelona.cat/data...
# 46  https://opendata-ajuntament.barcelona.cat/data...
# 47  https://opendata-ajuntament.barcelona.cat/data...
# 48  https://opendata-ajuntament.barcelona.cat/data...
# 49  https://opendata-ajuntament.barcelona.cat/data...
#
#                                         name
# 0                      ITINERARIS_ITINERARIS
# 1    2021_01_Gener_ITINERARIS_ITINERARIS.csv
# 2   2021_02_Febrer_ITINERARIS_ITINERARIS.csv
# 3         2021_03_Marc_ITINERARIS_ITINERARIS
# 4    2021_04_Abril_ITINERARIS_ITINERARIS.csv
# 5     2021_05_Maig_ITINERARIS_ITINERARIS.csv
# 6     2021_06_Juny_ITINERARIS_ITINERARIS.csv
# 7       2021_07_Juliol_ITINERARIS_ITINERARIS
# 8        2021_08_Agost_ITINERARIS_ITINERARIS
# 9     2021_09_Setembre_ITINERARIS_ITINERARIS
# 10     2021_10_Octubre_ITINERARIS_ITINERARIS
# 11    2021_11_Novembre_ITINERARIS_ITINERARIS
# 12       2020_01_Gener_ITINERARIS_ITINERARIS
# 13      2020_02_Febrer_ITINERARIS_ITINERARIS
# 14        2020_03_Marc_ITINERARIS_ITINERARIS
# 15       2020_04_Abril_ITINERARIS_ITINERARIS
# 16        2020_05_Maig_ITINERARIS_ITINERARIS
# 17        2020_06_Juny_ITINERARIS_ITINERARIS
# 18      2020_07_Juliol_ITINERARIS_ITINERARIS
# 19       2020_08_Agost_ITINERARIS_ITINERARIS
# 20    2020_09_Setembre_ITINERARIS_ITINERARIS
# 21     2020_10_Octubre_ITINERARIS_ITINERARIS
# 22    2020_11_Novembre_ITINERARIS_ITINERARIS
# 23    2020_12_Desembre_ITINERARIS_ITINERARIS
# 24       2019_01_Gener_ITINERARIS_ITINERARIS
# 25      2019_02_Febrer_ITINERARIS_ITINERARIS
# 26        2019_03_Marc_ITINERARIS_ITINERARIS
# 27       2019_04_Abril_ITINERARIS_ITINERARIS
# 28        2019_05_Maig_ITINERARIS_ITINERARIS
# 29        2019_06_Juny_ITINERARIS_ITINERARIS
# 30      2019_07_Juliol_ITINERARIS_ITINERARIS
# 31       2019_08_Agost_ITINERARIS_ITINERARIS
# 32    2019_09_Setembre_ITINERARIS_ITINERARIS
# 33     2019_10_Octubre_ITINERARIS_ITINERARIS
# 34    2019_11_Novembre_ITINERARIS_ITINERARIS
# 35    2019_12_Desembre_ITINERARIS_ITINERARIS
# 36       2018_01_Gener_ITINERARIS_ITINERARIS
# 37      2018_02_Febrer_ITINERARIS_ITINERARIS
# 38        2018_03_Marc_ITINERARIS_ITINERARIS
# 39       2018_04_Abril_ITINERARIS_ITINERARIS
# 40        2018_05_Maig_ITINERARIS_ITINERARIS
# 41        2018_06_Juny_ITINERARIS_ITINERARIS
# 42      2018_07_Juliol_ITINERARIS_ITINERARIS
# 43       2018_08_Agost_ITINERARIS_ITINERARIS
# 44    2018_09_Setembre_ITINERARIS_ITINERARIS
# 45     2018_10_Octubre_ITINERARIS_ITINERARIS
# 46    2018_11_Novembre_ITINERARIS_ITINERARIS
# 47    2018_12_Desembre_ITINERARIS_ITINERARIS
# 48    2017_11_Novembre_ITINERARIS_ITINERARIS
# 49    2017_12_Desembre_ITINERARIS_ITINERARIS
